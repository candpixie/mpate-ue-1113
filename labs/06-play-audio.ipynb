# %%
# Uncomment the line below
# if you need to install Librosa

# !pip install librosa

# %%
from IPython.display import Audio
import librosa

# %%
# Change to your file
filename = "audio/001.wav"

x, y = librosa.load(filename)
print("Number of Samples: ", len(x))
print("Sample Rate: ", y)

for i in range(0,9):
    print("Sample ", i, " is ", x[i])

# %%
Audio(x, rate=y)
