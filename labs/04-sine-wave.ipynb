# %%
import numpy as np
from IPython.display import Audio
import matplotlib.pyplot as plt

# %%
duration = 5
sampleRate = 44100
frequency = 440
pi = 3.141592654

time = np.linspace(0,duration,sampleRate * duration)

sineWave = np.sin(2 * pi * time * frequency)
Audio(sineWave,rate=sampleRate)

# %%
plt.plot(sineWave[1:500])
